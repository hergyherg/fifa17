# %% [markdown]
# # Exploring FIFA 17 Dataset

# %% [markdown]
# ## Importation, Setup, Read...

# %% [markdown]
# ### Import Python Modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
# %matplotlib inline

import math

import seaborn as sns

from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# Disable scrolling capability for notebook outputs

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
plt.style.use('fivethirtyeight') #FiveThirtyEight.com Style

# %% [markdown]
# ### Read Data

# %%
df_players = pd.read_csv('fifa_full.csv')

# %%
df_players.head(5)
# Out:
#                 Name Nationality National_Position  National_Kit  \
# 0  Cristiano Ronaldo    Portugal                LS           7.0
# 1       Lionel Messi   Argentina                RW          10.0
# 2             Neymar      Brazil                LW          10.0
# 3        Luis Suárez     Uruguay                LS           9.0
# 4       Manuel Neuer     Germany                GK           1.0
#
#            Club Club_Position  Club_Kit Club_Joining  Contract_Expiry  Rating  \
# 0   Real Madrid            LW       7.0   07/01/2009           2021.0      94
# 1  FC Barcelona            RW      10.0   07/01/2004           2018.0      93
# 2  FC Barcelona            LW      11.0   07/01/2013           2021.0      92
# 3  FC Barcelona            ST       9.0   07/11/2014           2021.0      92
# 4     FC Bayern            GK       1.0   07/01/2011           2021.0      92
#
#       ...      Long_Shots Curve Freekick_Accuracy Penalties  Volleys  \
# 0     ...              90    81                76        85       88
# 1     ...              88    89                90        74       85
# 2     ...              77    79                84        81       83
# 3     ...              86    86                84        85       88
# 4     ...              16    14                11        47       11
#
#   GK_Positioning GK_Diving  GK_Kicking  GK_Handling  GK_Reflexes
# 0             14         7          15           11           11
# 1             14         6          15           11            8
# 2             15         9          15            9           11
# 3             33        27          31           25           37
# 4             91        89          95           90           89
#
# [5 rows x 53 columns]

# %% [markdown]
# ## Data Engineering

# %% [markdown]
# ### Account for Missing Values

# %%
missing_values = df_players.isnull().sum()/len(df_players)*100

# %%
missing_values
# Out:
# Name                   0.000000
# Nationality            0.000000
# National_Position     93.887878
# National_Kit          93.887878
# Club                   0.000000
# Club_Position          0.005686
# Club_Kit               0.005686
# Club_Joining           0.005686
# Contract_Expiry        0.005686
# Rating                 0.000000
# Height                 0.000000
# Weight                 0.000000
# Preffered_Foot         0.000000
# Birth_Date             0.000000
# Age                    0.000000
# Preffered_Position     0.000000
# Work_Rate              0.000000
# Weak_foot              0.000000
# Skill_Moves            0.000000
# Ball_Control           0.000000
# Dribbling              0.000000
# Marking                0.000000
# Sliding_Tackle         0.000000
# Standing_Tackle        0.000000
# Aggression             0.000000
# Reactions              0.000000
# Attacking_Position     0.000000
# Interceptions          0.000000
# Vision                 0.000000
# Composure              0.000000
# Crossing               0.000000
# Short_Pass             0.000000
# Long_Pass              0.000000
# Acceleration           0.000000
# Speed                  0.000000
# Stamina                0.000000
# Strength               0.000000
# Balance                0.000000
# Agility                0.000000
# Jumping                0.000000
# Heading                0.000000
# Shot_Power             0.000000
# Finishing              0.000000
# Long_Shots             0.000000
# Curve                  0.000000
# Freekick_Accuracy      0.000000
# Penalties              0.000000
# Volleys                0.000000
# GK_Positioning         0.000000
# GK_Diving              0.000000
# GK_Kicking             0.000000
# GK_Handling            0.000000
# GK_Reflexes            0.000000
# dtype: float64

# %% [markdown]
# Delete columns missing majority of data. Nationality columns have ~90% of data missing.

# %%
df_players.drop(df_players.columns[[2,3]], axis = 1, inplace = True)
df_players.dropna(how='any', inplace = True)

# %% [markdown]
# Separate DataFrame into GKs and non-GKs due to distinct skillsets.

# %%
df_gks = df_players[df_players['Preffered_Position'] == 'GK']
df_gks.reset_index(drop = True)
df_players = df_players[df_players['Preffered_Position'] != 'GK']
df_players.reset_index(drop = True)
# Out:
#                             Name          Nationality             Club  \
# 0              Cristiano Ronaldo             Portugal      Real Madrid
# 1                   Lionel Messi            Argentina     FC Barcelona
# 2                         Neymar               Brazil     FC Barcelona
# 3                    Luis Suárez              Uruguay     FC Barcelona
# 4             Robert Lewandowski               Poland        FC Bayern
# 5                    Gareth Bale                Wales      Real Madrid
# 6             Zlatan Ibrahimović               Sweden   Manchester Utd
# 7                 Jérôme Boateng              Germany        FC Bayern
# 8                    Eden Hazard              Belgium          Chelsea
# 9                    Luka Modrić              Croatia      Real Madrid
# 10                    Mesut Özil              Germany          Arsenal
# 11               Gonzalo Higuaín            Argentina         Juventus
# 12                  Thiago Silva               Brazil              PSG
# 13                  Sergio Ramos                Spain      Real Madrid
# 14                 Sergio Agüero            Argentina  Manchester City
# 15                    Paul Pogba               France   Manchester Utd
# 16             Antoine Griezmann               France  Atlético Madrid
# 17               Kevin De Bruyne              Belgium  Manchester City
# 18                    Marco Reus              Germany    Bor. Dortmund
# 19                Alexis Sánchez                Chile          Arsenal
# 20                    Toni Kroos              Germany      Real Madrid
# 21                   Diego Godín              Uruguay  Atlético Madrid
# 22                  Mats Hummels              Germany        FC Bayern
# 23             Giorgio Chiellini                Italy         Juventus
# 24                  Philipp Lahm              Germany        FC Bayern
# 25                          Pepe             Portugal      Real Madrid
# 26                       Iniesta                Spain     FC Barcelona
# 27               James Rodríguez             Colombia      Real Madrid
# 28     Pierre-Emerick Aubameyang                Gabon    Bor. Dortmund
# 29              Leonardo Bonucci                Italy         Juventus
# ...                          ...                  ...              ...
# 15554              Kesi Omolokun              England         Aberdeen
# 15555               Louis Wardle              England         Barnsley
# 15556               Carl Stewart              England          Watford
# 15557              Ollie Bassett              England      Yeovil Town
# 15558                Ryan Wintle              England  Crewe Alexandra
# 15559              Oliver Finney              England  Crewe Alexandra
# 15560                Dan Sweeney              England           Barnet
# 15561             Robert Spelman  Republic of Ireland    Galway United
# 15562                Jordy Delem               France      Sounders FC
# 15563             Owen McCormack  Republic of Ireland   Wexford Youths
# 15564               Conor Sutton  Republic of Ireland   Wexford Youths
# 15565              Kieran Butler  Republic of Ireland   Bray Wanderers
# 15566                  Kyle Egan              England      Exeter City
# 15567              Alfie Kilgour              England   Bristol Rovers
# 15568               Shane Hanney  Republic of Ireland  Shamrock Rovers
# 15569               Kaylen Hinds              England        Stevenage
# 15570                 James King              England    Bradford City
# 15571            Neil McLaughlin             Scotland  Partick Thistle
# 15572            Nathan Clifford  Republic of Ireland       Finn Harps
# 15573               Ciaran Kelly  Republic of Ireland       Finn Harps
# 15574            Dominic Peppard  Republic of Ireland      Bohemian FC
# 15575            Tommy Käßemodel              Germany   Erzgebirge Aue
# 15576               Ronan Wilson     Northern Ireland       Derry City
# 15577            Darragh Doherty  Republic of Ireland    Longford Town
# 15578                 Myles Judd              England    Leyton Orient
# 15579              Steven Alzate              England    Leyton Orient
# 15580                  Sam Dalby              England    Leyton Orient
# 15581              Henry Ochieng              England    Leyton Orient
# 15582              Harry Clifton              England     Grimsby Town
# 15583            Tommy Ouldridge              England     Swindon Town
#
#       Club_Position  Club_Kit Club_Joining  Contract_Expiry  Rating  Height  \
# 0                LW       7.0   07/01/2009           2021.0      94  185 cm
# 1                RW      10.0   07/01/2004           2018.0      93  170 cm
# 2                LW      11.0   07/01/2013           2021.0      92  174 cm
# 3                ST       9.0   07/11/2014           2021.0      92  182 cm
# 4                ST       9.0   07/01/2014           2021.0      90  185 cm
# 5                RW      11.0   09/02/2013           2022.0      90  183 cm
# 6                ST       9.0   07/01/2016           2017.0      90  195 cm
# 7               Sub      17.0   07/14/2011           2021.0      89  192 cm
# 8                LW      10.0   07/01/2012           2020.0      89  173 cm
# 9               RCM      19.0   08/01/2012           2020.0      89  174 cm
# 10              CAM      11.0   09/02/2013           2018.0      89  180 cm
# 11               ST       9.0   07/26/2016           2021.0      89  184 cm
# 12              LCB       2.0   07/01/2012           2020.0      89  183 cm
# 13              LCB       4.0   08/01/2005           2020.0      89  183 cm
# 14               ST      10.0   07/28/2011           2020.0      89  173 cm
# 15              LCM       6.0   08/09/2016           2021.0      88  191 cm
# 16               RS       7.0   07/29/2014           2021.0      88  176 cm
# 17              RCM      17.0   08/30/2015           2021.0      88  181 cm
# 18               LW      11.0   07/01/2012           2019.0      88  182 cm
# 19               ST       7.0   07/10/2014           2018.0      88  169 cm
# 20              LCM       8.0   07/17/2014           2022.0      88  182 cm
# 21              LCB       2.0   08/01/2010           2019.0      88  185 cm
# 22              LCB       5.0   07/01/2016           2021.0      88  191 cm
# 23              LCB       3.0   07/01/2005           2018.0      88  187 cm
# 24               RB      21.0   11/01/2002           2018.0      88  170 cm
# 25              RCB       3.0   07/01/2007           2017.0      88  188 cm
# 26               LM       8.0   07/01/2002           2018.0      88  171 cm
# 27              CAM      10.0   07/22/2014           2020.0      87  180 cm
# 28               ST      17.0   07/04/2013           2020.0      87  187 cm
# 29              RCB      19.0   07/01/2010           2021.0      87  190 cm
# ...             ...       ...          ...              ...     ...     ...
# 15554           Sub      49.0   08/01/2016           2017.0      48  173 cm
# 15555           Res      31.0   10/21/2015           2017.0      48  170 cm
# 15556           Res      35.0   07/01/2016           2020.0      48  174 cm
# 15557           Res      22.0   09/01/2015           2017.0      48  172 cm
# 15558           Sub      21.0   02/02/2015           2017.0      48  165 cm
# 15559           Sub      35.0   07/01/2015           2017.0      48  170 cm
# 15560           Res      39.0   12/22/2016           2018.0      48  191 cm
# 15561           Sub      15.0   01/01/2017           2020.0      47  176 cm
# 15562           Res      21.0   03/02/2017           2020.0      47  180 cm
# 15563           Sub      18.0   01/31/2016           2017.0      47  182 cm
# 15564           Sub      31.0   01/01/2016           2020.0      47  180 cm
# 15565           Res      30.0   04/25/2016           2017.0      47  185 cm
# 15566           Res      36.0   12/10/2015           2017.0      47  180 cm
# 15567           Res      32.0   10/13/2015           2020.0      47  178 cm
# 15568           Sub       2.0   02/01/2015           2017.0      47  182 cm
# 15569           Res      26.0   02/04/2015           2019.0      47  185 cm
# 15570           Res      21.0   09/16/2014           2023.0      47  177 cm
# 15571           Sub      26.0   05/26/2015           2017.0      47  177 cm
# 15572           Res      33.0   08/01/2015           2017.0      46  175 cm
# 15573           Sub      35.0   08/01/2015           2017.0      46  177 cm
# 15574           Sub      22.0   12/01/2016           2017.0      46  173 cm
# 15575           Res      29.0   07/01/2016           2017.0      46  173 cm
# 15576           Sub      35.0   01/01/2016           2017.0      46  184 cm
# 15577           Sub      26.0   01/01/2016           2020.0      46  178 cm
# 15578           Sub      29.0   09/01/2015           2017.0      46  178 cm
# 15579           Res      31.0   09/21/2016           2017.0      45  177 cm
# 15580           Sub      30.0   08/30/2016           2019.0      45  191 cm
# 15581           Sub      32.0   12/02/2016           2019.0      45  179 cm
# 15582           Res      15.0   06/30/2015           2017.0      45  180 cm
# 15583           Res      32.0   03/03/2015           2023.0      45  173 cm
#
#       Weight     ...      Long_Shots Curve  Freekick_Accuracy Penalties  \
# 0      80 kg     ...              90    81                 76        85
# 1      72 kg     ...              88    89                 90        74
# 2      68 kg     ...              77    79                 84        81
# 3      85 kg     ...              86    86                 84        85
# 4      79 kg     ...              82    77                 76        81
# 5      74 kg     ...              90    86                 85        76
# 6      95 kg     ...              88    82                 82        91
# 7      90 kg     ...              58    56                 31        46
# 8      74 kg     ...              82    82                 79        86
# 9      65 kg     ...              82    79                 77        80
# 10     76 kg     ...              76    84                 79        67
# 11     92 kg     ...              80    74                 62        70
# 12     79 kg     ...              71    61                 73        71
# 13     75 kg     ...              55    73                 67        68
# 14     70 kg     ...              84    82                 72        80
# 15     84 kg     ...              88    82                 82        76
# 16     67 kg     ...              82    84                 75        71
# 17     68 kg     ...              86    81                 84        77
# 18     76 kg     ...              85    90                 84        84
# 19     62 kg     ...              81    78                 78        77
# 20     78 kg     ...              88    85                 84        73
# 21     73 kg     ...              43    49                 51        50
# 22     92 kg     ...              51    65                 53        68
# 23     84 kg     ...              49    60                 31        50
# 24     66 kg     ...              65    77                 59        69
# 25     81 kg     ...              56    44                 47        57
# 26     68 kg     ...              74    80                 70        71
# 27     75 kg     ...              91    87                 86        81
# 28     80 kg     ...              79    78                 74        82
# 29     85 kg     ...              65    56                 61        70
# ...      ...     ...             ...   ...                ...       ...
# 15554  70 kg     ...              17    25                 23        32
# 15555  73 kg     ...              26    32                 26        30
# 15556  68 kg     ...              36    32                 36        35
# 15557  60 kg     ...              45    42                 43        49
# 15558  64 kg     ...              40    39                 43        41
# 15559  70 kg     ...              31    40                 42        29
# 15560  78 kg     ...              35    27                 31        32
# 15561  73 kg     ...              25    38                 35        42
# 15562  71 kg     ...              28    35                 39        41
# 15563  60 kg     ...              38    34                 29        46
# 15564  75 kg     ...              32    35                 30        38
# 15565  78 kg     ...              23    26                 25        35
# 15566  75 kg     ...              23    28                 28        35
# 15567  75 kg     ...              28    33                 24        35
# 15568  74 kg     ...              43    39                 41        44
# 15569  68 kg     ...              47    37                 26        62
# 15570  73 kg     ...              18    26                 16        32
# 15571  70 kg     ...              30    34                 30        39
# 15572  67 kg     ...              22    33                 28        20
# 15573  64 kg     ...              17    29                 25        28
# 15574  68 kg     ...              16    28                 20        31
# 15575  75 kg     ...              39    52                 37        41
# 15576  75 kg     ...              33    23                 21        36
# 15577  75 kg     ...              32    32                 33        40
# 15578  67 kg     ...              22    27                 29        33
# 15579  65 kg     ...              29    40                 22        35
# 15580  78 kg     ...              44    34                 23        40
# 15581  67 kg     ...              36    32                 31        36
# 15582  88 kg     ...              35    32                 27        24
# 15583  61 kg     ...              42    35                 36        42
#
#       Volleys  GK_Positioning  GK_Diving  GK_Kicking  GK_Handling  GK_Reflexes
# 0          88              14          7          15           11           11
# 1          85              14          6          15           11            8
# 2          83              15          9          15            9           11
# 3          88              33         27          31           25           37
# 4          86               8         15          12            6           10
# 5          76               5         15          11           15            6
# 6          93               9         13          10           15           12
# 7          53               6          7          15           12            5
# 8          79               8         11           6           12            8
# 9          74              14         13           7            9            9
# 10         77               6          6          10           14           14
# 11         88               5          5           7           12           10
# 12         63               9          9           5           12           10
# 13         66               7         11           9            8           11
# 14         85              11         13           6           15           14
# 15         84               4          5           2            6            3
# 16         87              13         14          14            8           14
# 17         82              10         15           5           13           13
# 18         88              13         12          13           12           11
# 19         83              12         10          15           10           13
# 20         82               7         10          13           11           10
# 21         47               5          6          15            8           15
# 22         60               5         15          10            6            6
# 23         45               4          3           2            3            3
# 24         66              14         11           5           12            5
# 25         23               9          8           5           15           10
# 26         74              13          6           6           13            7
# 27         91               5         15          15           15           14
# 28         86               9          6          15            9            9
# 29         55               2          2           3            2            4
# ...       ...             ...        ...         ...          ...          ...
# 15554      20              11          7          14            7            9
# 15555      21               8          9           8           12            6
# 15556      30              14         12           7           13           10
# 15557      42              12         11           5           10            9
# 15558      37              13          7           8           16           10
# 15559      38              11          8          10            9           13
# 15560      29               9         16           7            9           12
# 15561      26              14         10           8           15            9
# 15562      25              11         14          14            8            9
# 15563      27               6         12          12           12           11
# 15564      37              11         14          13           10            6
# 15565      24              12         12          12            8            6
# 15566      23               9          7          10            8            8
# 15567      19              10          6          11           11            5
# 15568      35              13         14          12            5           14
# 15569      36               9         15          13           11            6
# 15570      22              10          6           7           15           12
# 15571      41              14          8          15           16            9
# 15572      19              13         12           8           11            5
# 15573      17               7          7           9           14           15
# 15574      28               5         13           5           15           13
# 15575      34              13         10           6           12            6
# 15576      22              11         11          11            8           10
# 15577      26               9          7          14           10           10
# 15578      21              12          5          14            5           10
# 15579      30               7          9           6            6            6
# 15580      35              12          7          14           12            7
# 15581      25               7         12          12           13            9
# 15582      27               7          9           8            6           10
# 15583      37              15          7          13           14            7
#
# [15584 rows x 51 columns]

# %% [markdown]
# ### More Rigorous Position Attribute

# %% [markdown]
# As seen below, a player's preffered position varies greatly. We need to map the preffered position to a more rigorous definition. We will assume that the first position in the list is the most preffered position and therefore need to extract that value from the 'Preffered_Position' column.

# %%
np.unique(df_players['Preffered_Position'].values)
# Out:
# array(['CAM', 'CAM/CDM', 'CAM/CDM/LM', 'CAM/CF', 'CAM/CF/CDM', 'CAM/CF/ST',
#        'CAM/CM', 'CAM/CM/CDM', 'CAM/CM/CF', 'CAM/CM/LM', 'CAM/CM/RM',
#        'CAM/CM/ST', 'CAM/LB', 'CAM/LM', 'CAM/LM/CDM', 'CAM/LM/CM',
#        'CAM/LM/LW', 'CAM/LM/RM', 'CAM/LM/ST', 'CAM/LW', 'CAM/LWB',
#        'CAM/RB', 'CAM/RM', 'CAM/RM/CM', 'CAM/RM/LM', 'CAM/RM/LW',
#        'CAM/RM/ST', 'CAM/RW', 'CAM/RW/LW', 'CAM/RW/ST', 'CAM/RWB',
#        'CAM/ST', 'CAM/ST/CF', 'CAM/ST/CM', 'CB', 'CB/CDM', 'CB/CDM/CM',
#        'CB/CM', 'CB/CM/RM', 'CB/LB', 'CB/LB/CDM', 'CB/LM', 'CB/LM/LWB',
#        'CB/LWB', 'CB/RB', 'CB/RB/CM', 'CB/RM', 'CB/RWB', 'CB/ST', 'CDM',
#        'CDM/CAM', 'CDM/CAM/RM', 'CDM/CB', 'CDM/CB/RB', 'CDM/CM',
#        'CDM/CM/CAM', 'CDM/CM/RB', 'CDM/LB', 'CDM/LM', 'CDM/LM/CAM',
#        'CDM/LM/RM', 'CDM/RB', 'CDM/RB/CB', 'CDM/RB/RM', 'CDM/RM',
#        'CDM/RM/CAM', 'CDM/RM/RB', 'CDM/RWB', 'CF', 'CF/CAM', 'CF/CAM/RM',
#        'CF/CAM/ST', 'CF/CM', 'CF/LM', 'CF/LW', 'CF/RM', 'CF/RM/LM',
#        'CF/RW', 'CF/ST', 'CM', 'CM/CAM', 'CM/CAM/LM', 'CM/CAM/RM', 'CM/CB',
#        'CM/CDM', 'CM/CDM/CAM', 'CM/CDM/LM', 'CM/CDM/RB', 'CM/CDM/RM',
#        'CM/CF', 'CM/CF/RW', 'CM/LB', 'CM/LM', 'CM/LM/CAM', 'CM/LM/CB',
#        'CM/LM/CDM', 'CM/LM/RM', 'CM/LW', 'CM/LWB', 'CM/RB', 'CM/RB/CDM',
#        'CM/RB/RM', 'CM/RM', 'CM/RM/CAM', 'CM/RM/CDM', 'CM/RM/LB',
#        'CM/RM/LM', 'CM/RW', 'CM/RW/LW', 'CM/RWB', 'CM/ST', 'CM/ST/CDM',
#        'LB', 'LB/CAM', 'LB/CB', 'LB/CDM', 'LB/CDM/CM', 'LB/CM', 'LB/LM',
#        'LB/LM/LW', 'LB/LM/RM', 'LB/LW', 'LB/LWB', 'LB/LWB/CM',
#        'LB/LWB/RWB', 'LB/RB', 'LB/RM', 'LB/RW', 'LB/ST', 'LM', 'LM/CAM',
#        'LM/CAM/CM', 'LM/CAM/RB', 'LM/CAM/ST', 'LM/CDM', 'LM/CF', 'LM/CM',
#        'LM/CM/CAM', 'LM/CM/CB', 'LM/CM/RM', 'LM/LB', 'LM/LW', 'LM/LW/LB',
#        'LM/LWB', 'LM/RB', 'LM/RM', 'LM/RM/CF', 'LM/RM/CM', 'LM/RM/LB',
#        'LM/RM/RW', 'LM/RM/ST', 'LM/RW', 'LM/ST', 'LM/ST/CAM', 'LM/ST/CB',
#        'LW', 'LW/CAM', 'LW/CAM/CF', 'LW/CAM/LM', 'LW/CAM/ST', 'LW/CF',
#        'LW/CM', 'LW/LB', 'LW/LM', 'LW/LM/LB', 'LW/LM/RM', 'LW/LWB',
#        'LW/RM', 'LW/RW', 'LW/RW/CAM', 'LW/ST', 'LW/ST/CF', 'LWB', 'LWB/CB',
#        'LWB/CDM', 'LWB/CM/RWB', 'LWB/LB', 'LWB/LM', 'LWB/LW', 'LWB/RM',
#        'LWB/RWB', 'RB', 'RB/CAM', 'RB/CAM/CM', 'RB/CB', 'RB/CB/RWB',
#        'RB/CDM', 'RB/CDM/CB', 'RB/CM', 'RB/LB', 'RB/LB/CDM', 'RB/LB/CM',
#        'RB/LM', 'RB/LM/CAM', 'RB/LWB', 'RB/RM', 'RB/RM/CAM', 'RB/RM/CDM',
#        'RB/RM/LB', 'RB/RM/LM', 'RB/RW', 'RB/RW/LW', 'RB/RW/RWB', 'RB/RWB',
#        'RB/ST', 'RM', 'RM/CAM', 'RM/CAM/CDM', 'RM/CAM/CM', 'RM/CAM/LM',
#        'RM/CAM/ST', 'RM/CB', 'RM/CDM', 'RM/CDM/LM', 'RM/CF', 'RM/CF/LW',
#        'RM/CM', 'RM/CM/CAM', 'RM/CM/CDM', 'RM/CM/LWB', 'RM/LB', 'RM/LM',
#        'RM/LM/CAM', 'RM/LM/CDM', 'RM/LM/CM', 'RM/LM/RB', 'RM/LW',
#        'RM/LW/LM', 'RM/LW/RW', 'RM/RB', 'RM/RW', 'RM/RW/LW', 'RM/RW/RWB',
#        'RM/RWB', 'RM/ST', 'RW', 'RW/CAM', 'RW/CAM/ST', 'RW/CF', 'RW/CF/RM',
#        'RW/CM', 'RW/CM/LW', 'RW/LB', 'RW/LM', 'RW/LM/LW', 'RW/LW',
#        'RW/LW/CF', 'RW/LW/CM', 'RW/LW/RM', 'RW/LW/ST', 'RW/RB', 'RW/RM',
#        'RW/RM/LW', 'RW/RM/ST', 'RW/ST', 'RW/ST/CM', 'RW/ST/LM', 'RWB',
#        'RWB/CM', 'RWB/LB', 'RWB/LM', 'RWB/LWB', 'RWB/RB', 'RWB/RM', 'ST',
#        'ST/CAM', 'ST/CAM/LM', 'ST/CB', 'ST/CDM', 'ST/CF', 'ST/CF/CAM',
#        'ST/CF/RM', 'ST/CM', 'ST/LB', 'ST/LM', 'ST/LM/CAM', 'ST/LM/CF',
#        'ST/LM/RB', 'ST/LM/RM', 'ST/LW', 'ST/LW/LM', 'ST/LW/RW', 'ST/RM',
#        'ST/RM/CAM', 'ST/RM/LW', 'ST/RM/RW', 'ST/RW', 'ST/RW/LM',
#        'ST/RW/LW', 'ST/RW/RM', 'ST/RWB'], dtype=object)

# %%
def map_position(pref_list):
    if len(pref_list) == 2 or len(pref_list) == 3:
        new = pref_list
    else:
        index = pref_list.find('/')
        new = pref_list[:index]
        
    if new == 'CF':
        return 'ST'
    if new == 'LWB':
        return 'LB'
    if new == 'RWB':
        return 'RB'
    return new

# %%
# Create new column for mapped position
df_players['Position'] = df_players['Preffered_Position'].map(map_position)

# %%
np.unique(df_players['Position'].values)
# Out:
# array(['CAM', 'CB', 'CDM', 'CM', 'LB', 'LM', 'LW', 'RB', 'RM', 'RW', 'ST'], dtype=object)

# %%
np.unique(df_gks['Preffered_Position'].values)
# Out:
# array(['GK'], dtype=object)

# %%
# Drop old position column, no longer needed
df_players.drop('Preffered_Position', axis = 1, inplace = True)

# %%
df_players.columns
# Out:
# Index(['Name', 'Nationality', 'Club', 'Club_Position', 'Club_Kit',
#        'Club_Joining', 'Contract_Expiry', 'Rating', 'Height', 'Weight',
#        'Preffered_Foot', 'Birth_Date', 'Age', 'Work_Rate', 'Weak_foot',
#        'Skill_Moves', 'Ball_Control', 'Dribbling', 'Marking', 'Sliding_Tackle',
#        'Standing_Tackle', 'Aggression', 'Reactions', 'Attacking_Position',
#        'Interceptions', 'Vision', 'Composure', 'Crossing', 'Short_Pass',
#        'Long_Pass', 'Acceleration', 'Speed', 'Stamina', 'Strength', 'Balance',
#        'Agility', 'Jumping', 'Heading', 'Shot_Power', 'Finishing',
#        'Long_Shots', 'Curve', 'Freekick_Accuracy', 'Penalties', 'Volleys',
#        'GK_Positioning', 'GK_Diving', 'GK_Kicking', 'GK_Handling',
#        'GK_Reflexes', 'Position'],
#       dtype='object')

# %% [markdown]
# ## Trippy Visuals

# %% [markdown]
# ### Attribute Box Plots

# %% [markdown]
# Divide attribute columns into different subsets to plot against each other.

# %%
overall_att = ['Rating']
pace_att = ['Acceleration', 'Speed']
shooting_att = ['Finishing', 'Shot_Power', 'Long_Shots', 'Volleys', 'Penalties', 'Attacking_Position']
dribble_att = ['Agility', 'Balance', 'Reactions', 'Ball_Control', 'Dribbling']
defense_att = ['Interceptions', 'Heading', 'Marking', 'Standing_Tackle', 'Sliding_Tackle']
pass_att = ['Vision', 'Crossing', 'Freekick_Accuracy', 'Short_Pass', 'Long_Pass', 'Curve']
phy_att = ['Jumping', 'Stamina', 'Strength', 'Aggression', 'Composure']
gk_att = ['GK_Positioning', 'GK_Diving', 'GK_Kicking', 'GK_Handling', 'GK_Reflexes']

# %%
df_gks_melt = pd.melt(df_gks, id_vars = ['Name'], value_vars = gk_att, var_name = 'Attribute', value_name = 'Value')

# %%
plt.figure(figsize=(12,6))
plt.title('Goalkeeper Attribute Box Plot', loc = 'center', weight = 'bold')
ax = sns.boxplot(x = 'Attribute', y = 'Value', data = df_gks_melt)

# %%
df_pl_att = pd.melt(df_players, id_vars = ['Name'], value_vars = shooting_att, var_name = 'Attribute', value_name = 'Value')

# %%
plt.figure(figsize=(12,6))
plt.title('Shooting Attribute Box Plot', loc = 'center', weight = 'bold')
ax = sns.boxplot(x = 'Attribute', y = 'Value', data = df_pl_att)

# %% [markdown]
# ### Attributes by Position

# %%
pos_avgs = df_players.groupby('Position').mean()

# %% [markdown]
# Sort table using a manually defined sort: most attacking players to least.

# %%
positions = ['ST', 'RW', 'RM','LW', 'LM', 'CAM', 'CM', 'CDM', 'RB','LB', 'CB']
mapping = {pos: i for i, pos in enumerate(positions)}
pos_avgs['sorted'] = pos_avgs.index.map(mapper=(lambda x: mapping[x]))
pos_avgs.sort_values(by='sorted', ascending = True, inplace = True)
pos_avgs.head(11)
# Out:
#            Club_Kit  Contract_Expiry     Rating        Age  Weak_foot  \
# Position
# ST        23.599085      2018.935976  66.087652  25.234375   3.071646
# RW        23.803419      2019.176638  66.390313  23.455840   3.105413
# RM        21.303554      2018.887608  66.645533  25.020173   3.146013
# LW        23.860927      2018.917219  67.304636  24.165563   3.235099
# LM        22.529781      2018.932079  66.980146  25.000000   3.129572
# CAM       23.098361      2018.989982  67.184882  24.908925   3.211293
# CM        20.782543      2018.857719  65.234107  24.784057   3.088799
# CDM       19.868919      2019.026351  67.294595  26.231081   2.991892
# RB        20.451909      2018.805516  65.871994  25.509901   2.905233
# LB        19.917084      2018.894925  65.836312  25.341673   2.789850
# CB        18.852861      2018.887262  66.788488  25.947548   2.777248
#
#           Skill_Moves  Ball_Control  Dribbling    Marking  Sliding_Tackle  \
# Position
# ST           2.624238     64.382241  63.211509  22.611662       23.028963
# RW           3.094017     68.142450  69.860399  27.643875       30.022792
# RM           2.951009     66.963497  68.541787  34.040346       35.618636
# LW           3.102649     69.142384  71.072848  28.019868       29.791391
# LM           2.965517     67.626959  69.118077  33.471264       35.336468
# CAM          3.067395     68.720401  68.520036  36.093807       37.940801
# CM           2.504541     66.554995  63.682139  51.709889       54.721998
# CDM          2.193243     65.049324  59.493919  62.981081       63.445270
# RB           2.190948     61.109618  59.767327  63.359972       65.765912
# LB           2.218728     61.635454  61.149392  62.994996       65.575411
# CB           2.010218     52.709809  42.930858  65.814373       65.613760
#
#            ...        Curve  Freekick_Accuracy  Penalties    Volleys  \
# Position   ...
# ST         ...    51.948552          45.398628  63.637195  58.903963
# RW         ...    58.561254          51.475783  58.472934  55.586895
# RM         ...    58.784822          52.512008  57.227666  53.980788
# LW         ...    60.172185          52.754967  58.960265  57.119205
# LM         ...    60.331243          54.065831  57.349007  54.355277
# CAM        ...    61.892532          58.746812  59.067395  55.592896
# CM         ...    56.661453          54.452573  54.545913  50.540363
# CDM        ...    50.980405          49.751351  51.813514  44.627027
# RB         ...    49.257426          41.591938  45.803395  39.047383
# LB         ...    52.604003          46.602573  46.743388  39.951394
# CB         ...    36.348093          35.296662  41.923706  32.557902
#
#           GK_Positioning  GK_Diving  GK_Kicking  GK_Handling  GK_Reflexes  \
# Position
# ST             10.629573  10.588415   10.718369    10.639863    10.605945
# RW             10.370370  10.621083   10.732194    10.518519    10.521368
# RM             10.651297  10.793468   10.929875    10.801153    10.594621
# LW             10.417219  10.503311   10.526490    10.493377    10.450331
# LM             10.607106  10.526646   10.715778    10.658307    10.647858
# CAM            10.693078  10.594718   10.715847    10.690346    10.693989
# CM             10.505045  10.393542   10.447528    10.561049    10.531786
# CDM            10.850676  10.795270   10.864865    10.802027    10.775676
# RB             10.642150  10.705092   10.618812    10.709335    10.628713
# LB             10.656183  10.572552   10.596140    10.616154    10.595425
# CB             10.744210  10.622275   10.728883    10.621253    10.570163
#
#           sorted
# Position
# ST             0
# RW             1
# RM             2
# LW             3
# LM             4
# CAM            5
# CM             6
# CDM            7
# RB             8
# LB             9
# CB            10
#
# [11 rows x 41 columns]

# %%
fig, axs = plt.subplots(nrows = 11,ncols = 3, figsize=(15,40), sharex = True)

plt.suptitle('Attributes by Position (No GK)', fontsize = 24, y = 1.)

y_axis_list = list(pos_avgs.columns)[2:len(pos_avgs.columns)-6]
for i, col in enumerate(y_axis_list):
    row_num = i // 3
    col_num = i % 3
    max = pos_avgs[col].max()
    max = math.ceil(max/5)*5
    min = pos_avgs[col].min()
    min = math.floor(min/5)*5

    axs[row_num, col_num].set_ylim(min, max)
    pos_avgs[col].plot(kind='bar',
        ax = axs[row_num, col_num], color = sns.color_palette("husl", 11),
            title = col.replace('_', ' ').title(), alpha = 0.7)

        
patch_list = []
colors = sns.color_palette('husl', 11)

for i in range(len(positions)):
    patch_list.append(mpatches.Patch(color = colors[i], label = positions[i]))

plt.figlegend(handles = patch_list, labels = positions, loc = 'upper center',
              ncol = 11, bbox_to_anchor = (.5,.98), shadow = True)

plt.tight_layout()
plt.subplots_adjust(top = .95)

plt.savefig('attributes_by_position.png')
